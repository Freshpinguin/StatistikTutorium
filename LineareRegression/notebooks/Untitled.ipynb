# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([2,1,3])
y = np.array([2,1,1.5])

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.scatter(x,y)
X = np.arange(0,4,0.01)
plt.plot(X,X*0.25+1 )
plt.plot(X,2**X/3 )
plt.plot(X,-X**2+4*X-2 )
plt.plot(X,(11/42)*2**X )
